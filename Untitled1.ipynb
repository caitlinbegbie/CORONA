# %%
#checking the curve

# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('light_curve_42462.csv')

# Create the plot, specifying columns for x and y axes
plt.scatter(df['2458645.7875540005'], df['17.91973405300186'])

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.ylim(-50, 50)
plt.title('Title of the Graph')

# Show the graph
plt.show()

# %%
print(df.columns)
# Out:
# Index(['2458645.7875540005', '17.91973405300186', '0.002891109314860568',
#        '15.072813555127132', '0.01741993471311693', '15.072813555127132.1',
#        '0.01741993471311693.1', '15.072813555127132.2',
#        '0.01741993471311693.2', '1.2435324698725057', '8.99824257314717e-09',
#        '12.0', '2323.709619140625', '54.892374334223085', '861.9218674781857',
#        '687.3489488047708', '0.0'],
#       dtype='object')
