# %% [markdown]
# # Add columns in GAIA csvs

# %%
import numpy as np
import pandas as pd

# %%
def add_cols(file_path):
    df = pd.read_csv(file_path, comment='#', names=["Date", "JD (TCB)", "avg Mag"])
    df_print = print(df.head(128))
    return df

Gaia20bhi = pd.DataFrame(add_cols('Gaia20bhi.csv'))
print(Gaia20bhi)
# Out:
#                     Date      JD (TCB)    avg Mag
# 0              Gaia20bhi           NaN        NaN
# 1    2014-09-10 04:54:57  2.456911e+06  untrusted
# 2    2014-09-10 06:41:31  2.456911e+06  untrusted
# 3    2014-10-14 20:03:50  2.456945e+06  untrusted
# 4    2015-03-02 03:25:40  2.457084e+06        NaN
# ..                   ...           ...        ...
# 122  2023-05-04 01:37:02  2.460069e+06      19.91
# 123  2023-05-04 05:50:43  2.460069e+06  untrusted
# 124  2023-09-14 06:12:47  2.460202e+06        NaN
# 125  2023-09-14 07:58:52  2.460202e+06  untrusted
# 126  2023-10-15 13:30:56  2.460233e+06      19.02
#
# [127 rows x 3 columns]
#                     Date      JD (TCB)    avg Mag
# 0              Gaia20bhi           NaN        NaN
# 1    2014-09-10 04:54:57  2.456911e+06  untrusted
# 2    2014-09-10 06:41:31  2.456911e+06  untrusted
# 3    2014-10-14 20:03:50  2.456945e+06  untrusted
# 4    2015-03-02 03:25:40  2.457084e+06        NaN
# ...

# %%
Gaia20drp = pd.DataFrame(add_cols('Gaia20drp.csv'))
print(Gaia20drp)
# Out:
#                    Date      JD (TCB)    avg Mag
# 0             Gaia20drp           NaN        NaN
# 1   2014-10-09 14:10:37  2.456940e+06  untrusted
# 2   2014-10-09 15:57:10  2.456940e+06  untrusted
# 3   2015-02-25 03:36:22  2.457079e+06        NaN
# 4   2015-02-25 05:23:07  2.457079e+06        NaN
# ..                  ...           ...        ...
# 92  2022-03-31 22:40:34  2.459670e+06      18.65
# 93  2022-04-01 00:27:08  2.459671e+06      18.65
# 94  2022-04-16 16:50:06  2.459686e+06      18.00
# 95  2022-04-16 18:36:41  2.459686e+06      18.02
# 96  2022-04-16 22:50:22  2.459686e+06      17.99
#
# [97 rows x 3 columns]
#                    Date      JD (TCB)    avg Mag
# 0             Gaia20drp           NaN        NaN
# 1   2014-10-09 14:10:37  2.456940e+06  untrusted
# 2   2014-10-09 15:57:10  2.456940e+06  untrusted
# 3   2015-02-25 03:36:22  2.457079e+06        NaN
# 4   2015-02-25 05:23:07  2.457079e+06        NaN
# ..                  ...           ...        ...
# ...

# %%
Gaia16aau = pd.DataFrame(add_cols('Gaia16aau.csv'))
Gaia18dew = pd.DataFrame(add_cols('Gaia18dew.csv'))
Gaia20ayr = pd.DataFrame(add_cols('Gaia20ayr.csv'))
Gaia20bbh = pd.DataFrame(add_cols('Gaia20bbh.csv'))
Gaia20btw = pd.DataFrame(add_cols('Gaia20btw.csv'))
Gaia20cpt = pd.DataFrame(add_cols('Gaia20cpt.csv'))
Gaia20dvt = pd.DataFrame(add_cols('Gaia20dvt.csv'))
Gaia20fay = pd.DataFrame(add_cols('Gaia20fay.csv'))
Gaia20fda = pd.DataFrame(add_cols('Gaia20fda.csv'))
Gaia23aez = pd.DataFrame(add_cols('Gaia23aez.csv'))
Gaia23bmd = pd.DataFrame(add_cols('Gaia23bmd.csv'))
Gaia24bst = pd.DataFrame(add_cols('Gaia24bst.csv'))
Gaia24cdx = pd.DataFrame(add_cols('Gaia24cdx.csv'))
Gaia24cfd = pd.DataFrame(add_cols('Gaia24cfd.csv'))
# Out:
#                     Date      JD (TCB)    avg Mag
# 0              Gaia16aau           NaN        NaN
# 1    2014-08-30 04:04:29  2.456900e+06        NaN
# 2    2014-08-30 05:51:14  2.456900e+06        NaN
# 3    2014-10-10 14:59:48  2.456941e+06  untrusted
# 4    2014-11-11 20:33:37  2.456973e+06      20.76
# ..                   ...           ...        ...
# 123  2021-08-07 03:03:03  2.459434e+06      14.32
# 124  2021-08-07 04:49:38  2.459434e+06      14.32
# 125  2021-09-03 09:05:37  2.459461e+06      14.40
# 126  2021-09-03 10:52:11  2.459461e+06      14.38
# 127  2021-10-11 14:40:40  2.459499e+06      14.38
#
# [128 rows x 3 columns]
#                     Date      JD (TCB) avg Mag
# 0              Gaia18dew           NaN     NaN
# 1    2014-08-12 09:16:19  2.456882e+06   14.99
# 2    2014-08-12 15:16:34  2.456882e+06   14.82
# 3    2014-08-12 19:30:15  2.456882e+06   14.90
# 4    2014-08-12 21:16:49  2.456882e+06   14.88
# ..                   ...           ...     ...
# ...

# %%
print(Gaia23aez)
# Out:
#                     Date      JD (TCB)    avg Mag
# 0              Gaia23aez           NaN        NaN
# 1    2014-11-01 02:51:01  2.456963e+06      10.23
# 2    2014-11-01 04:37:35  2.456963e+06      10.20
# 3    2014-12-01 16:15:07  2.456993e+06  untrusted
# 4    2014-12-27 22:10:08  2.457019e+06  untrusted
# ..                   ...           ...        ...
# 208  2024-01-01 19:50:21  2.460311e+06        NaN
# 209  2024-01-02 00:03:34  2.460312e+06      10.64
# 210  2024-01-02 01:50:08  2.460312e+06      10.64
# 211  2024-01-23 06:11:31  2.460333e+06      10.60
# 212  2024-01-23 07:58:05  2.460333e+06      10.59
#
# [213 rows x 3 columns]

# %%
new_Gaia16aau = Gaia16aau.to_csv('new_Gaia16aau.csv', index = False)
new_Gaia18dew = Gaia18dew.to_csv('new_Gaia18dew.csv', index = False)
new_Gaia20ayr = Gaia20ayr.to_csv('new_Gaia20ayr.csv', index = False)
new_Gaia20bbh = Gaia20bbh.to_csv('new_Gaia20bbh.csv', index = False)
new_Gaia20btw = Gaia20btw.to_csv('new_Gaia20btw.csv', index = False)
new_Gaia20cpt = Gaia20cpt.to_csv('new_Gaia20cpt.csv', index = False)
new_Gaia20dvt = Gaia20dvt.to_csv('new_Gaia20dvt.csv', index = False)
new_Gaia20fay = Gaia20fay.to_csv('new_Gaia20fay.csv', index = False)
new_Gaia20fda = Gaia20fda.to_csv('new_Gaia20fda.csv', index = False)
new_Gaia23aez = Gaia23aez.to_csv('new_Gaia23aez.csv', index = False)
new_Gaia23bmd = Gaia23bmd.to_csv('new_Gaia23bmd.csv', index = False)
new_Gaia24bst = Gaia24bst.to_csv('new_Gaia24bst.csv', index = False)
new_Gaia24cdx = Gaia24cdx.to_csv('new_Gaia24cdx.csv', index = False)
new_Gaia24cfd = Gaia24cfd.to_csv('new_Gaia24cfd.csv', index = False)
new_Gaia20drp = Gaia20drp.to_csv('new_Gaia20drp.csv', index = False)
new_Gaia20bhi = Gaia20bhi.to_csv('new_Gaia20bhi.csv', index = False)
