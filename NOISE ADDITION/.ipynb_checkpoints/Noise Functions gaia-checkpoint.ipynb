# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import os
import numpy as np
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"

df1 = pd.read_csv('new_Gaia16aau.csv')
print(len(df1))
# Out:
# 167

# %%
df_n = pd.read_csv('light_curve_42462.csv')

def add_noise_1(folder_path, col1_name, col2_name, residual_x, residual_y):
    """
    Adds two new columns to each CSV file in a folder and saves the modified DataFrames as new CSV files.

    Args:
        folder_path (str): The path to the folder containing the CSV files.
        col1_name (str): The name of the first new column.
        col2_name (str): The name of the second new column.
        residual_x (list): A list of values for the first new column.
        residual_y (list): A list of values for the second new column.
    """
    target_length = len(residual_x)

    if not os.path.exists(folder_path):
        raise FileNotFoundError(f"The folder '{folder_path}' does not exist.")
    
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            file_path = os.path.join(folder_path, filename)
            try:
                df = pd.read_csv(file_path)
            except pd.errors.EmptyDataError:
                print(f"Warning: '{filename}' is empty and will be skipped.")
                continue

            # Debug: Check the length of the DataFrame and residuals
            print(f"Checking file: {filename}")
            print(f"DataFrame length: {len(df)}, Residual length: {target_length}")

            # If the DataFrame length doesn't match, adjust it
            if len(df) < target_length:
                # Pad the DataFrame with NaN values
                padding_needed = target_length - len(df)
                print(f"Padding {filename} with {padding_needed} NaN rows.")
                nan_series = pd.Series([np.nan] * padding_needed)
                df = pd.concat([df, nan_series], ignore_index=True)
            elif len(df) > target_length:
                # Truncate the DataFrame to match the residual length
                print(f"Truncating {filename} to {target_length} rows.")
                df = df.iloc[:target_length]

            # Now the DataFrame length matches the residuals length
            df[col1_name] = residual_x
            df[col2_name] = residual_y

            # Save the modified DataFrame to a new file
            new_filename = f"noisey1_{filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f"Noise added to '{new_filename}'")

            try:
                os.remove(file_path)
                print(f"Deleted the original file: {filename}")
            except Exception as e:
                print(f"Failed to delete the original file {filename}: {e}")

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import os
import numpy as np
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"

def scale2(folder_path):
    """
    Scales the mag values
    """

    if not os.path.exists(folder_path):
        raise FileNotFoundError(f"The folder '{folder_path}' does not exist.")
    
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            file_path = os.path.join(folder_path, filename)
            try:
                df = pd.read_csv(file_path)
            except pd.errors.EmptyDataError:
                print(f"Warning: '{filename}' is empty and will be skipped.")
                continue

            # Debug: shows that we got this far
            print(f"Checking file: {filename}")

            cols_to_scale = [df.columns[1], df.columns[2], df.columns[3], df.columns[4], df.columns[5], df.columns[6]]
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.95
                
            # Save the modified DataFrame to a new file
            new_filename = f"0.95jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.95")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.05

            # Save the modified DataFrame to a new file
            new_filename = f"1.05jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.05")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.88

            # Save the modified DataFrame to a new file
            new_filename = f"0.88jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.88")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.07

            # Save the modified DataFrame to a new file
            new_filename = f"1.07jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.07")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.01

            # Save the modified DataFrame to a new file
            new_filename = f"1.01jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.01")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.85

            # Save the modified DataFrame to a new file
            new_filename = f"0.85jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.85")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.65

            # Save the modified DataFrame to a new file
            new_filename = f"0.65jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.65")
            
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.55

            # Save the modified DataFrame to a new file
            new_filename = f"0.55jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.55")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.75

            # Save the modified DataFrame to a new file
            new_filename = f"0.75jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.75")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.25

            # Save the modified DataFrame to a new file
            new_filename = f"0.25jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.25")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.58

            # Save the modified DataFrame to a new file
            new_filename = f"0.58jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.58")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.28

            # Save the modified DataFrame to a new file
            new_filename = f"1.28jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.28")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.55

            # Save the modified DataFrame to a new file
            new_filename = f"1.55jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.55")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.37

            # Save the modified DataFrame to a new file
            new_filename = f"1.37jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.37")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.43

            # Save the modified DataFrame to a new file
            new_filename = f"1.43jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.43")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.42

            # Save the modified DataFrame to a new file
            new_filename = f"1.42jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.42")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.44

            # Save the modified DataFrame to a new file
            new_filename = f"1.44jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.44")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.45

            # Save the modified DataFrame to a new file
            new_filename = f"1.45jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.45")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.46

            # Save the modified DataFrame to a new file
            new_filename = f"1.46jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.46")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.47

            # Save the modified DataFrame to a new file
            new_filename = f"1.47jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.47")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.48

            # Save the modified DataFrame to a new file
            new_filename = f"1.48jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.48")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.49

            # Save the modified DataFrame to a new file
            new_filename = f"1.49jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.49")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.51

            # Save the modified DataFrame to a new file
            new_filename = f"1.51jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.51")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.52

            # Save the modified DataFrame to a new file
            new_filename = f"1.52jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.52")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.53

            # Save the modified DataFrame to a new file
            new_filename = f"1.53jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.53")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.54

            # Save the modified DataFrame to a new file
            new_filename = f"1.54jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.54")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.55

            # Save the modified DataFrame to a new file
            new_filename = f"1.55jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.55")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.56

            # Save the modified DataFrame to a new file
            new_filename = f"1.56jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.56")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.57

            # Save the modified DataFrame to a new file
            new_filename = f"1.57jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.57")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.58

            # Save the modified DataFrame to a new file
            new_filename = f"1.58jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.58")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.59

            # Save the modified DataFrame to a new file
            new_filename = f"1.59jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.59")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.4367

            # Save the modified DataFrame to a new file
            new_filename = f"1.4367jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.4367")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.435

            # Save the modified DataFrame to a new file
            new_filename = f"1.435jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.435") 
            
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 2

            # Save the modified DataFrame to a new file
            new_filename = f"2jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 2")v
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.431

            # Save the modified DataFrame to a new file
            new_filename = f"1.431jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.431")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 3

            # Save the modified DataFrame to a new file
            new_filename = f"3jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 3")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.999

            # Save the modified DataFrame to a new file
            new_filename = f"1.999jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.999")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.99

            # Save the modified DataFrame to a new file
            new_filename = f"0.99jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.99")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.444

            # Save the modified DataFrame to a new file
            new_filename = f"1.444jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.444")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.433

            # Save the modified DataFrame to a new file
            new_filename = f"1.433jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.433")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.437

            # Save the modified DataFrame to a new file
            new_filename = f"1.437jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.437")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.435

            # Save the modified DataFrame to a new file
            new_filename = f"1.435jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.435")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.66

            # Save the modified DataFrame to a new file
            new_filename = f"1.66jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.66")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.77

            # Save the modified DataFrame to a new file
            new_filename = f"1.77jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.77")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.458

            # Save the modified DataFrame to a new file
            new_filename = f"1.458jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.458")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.457

            # Save the modified DataFrame to a new file
            new_filename = f"1.457jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.457")
                        
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.43

            # Save the modified DataFrame to a new file
            new_filename = f"1.43jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.43")
# Out:
#   Cell In[15], line 326
#     print(f" '{new_filename}' scaled by 2")v
#                                            ^
# SyntaxError: invalid syntax

# %%
scale2("C:/Users/jacek/CORONA/gaia rcbs 1")
# Out:
# Checking file: noisey1_new_Gaia16aau.csv
#  '0.95jds noisey1_new_Gaia16aau.csv' scaled by 0.95
#  '1.05jds noisey1_new_Gaia16aau.csv' scaled by 1.05
#  '0.88jds noisey1_new_Gaia16aau.csv' scaled by 0.88
#  '1.07jds noisey1_new_Gaia16aau.csv' scaled by 1.07
#  '1.01jds noisey1_new_Gaia16aau.csv' scaled by 1.01
#  '0.85jds noisey1_new_Gaia16aau.csv' scaled by 0.85
# Checking file: noisey1_new_Gaia18dew.csv
#  '0.95jds noisey1_new_Gaia18dew.csv' scaled by 0.95
#  '1.05jds noisey1_new_Gaia18dew.csv' scaled by 1.05
#  '0.88jds noisey1_new_Gaia18dew.csv' scaled by 0.88
#  '1.07jds noisey1_new_Gaia18dew.csv' scaled by 1.07
#  '1.01jds noisey1_new_Gaia18dew.csv' scaled by 1.01
#  '0.85jds noisey1_new_Gaia18dew.csv' scaled by 0.85
# Checking file: noisey1_new_Gaia20ayr.csv
#  '0.95jds noisey1_new_Gaia20ayr.csv' scaled by 0.95
#  '1.05jds noisey1_new_Gaia20ayr.csv' scaled by 1.05
#  '0.88jds noisey1_new_Gaia20ayr.csv' scaled by 0.88
#  '1.07jds noisey1_new_Gaia20ayr.csv' scaled by 1.07
# ...

# %%
df_2 = pd.read_csv('light_curve_43000.csv')

folder_path = "C:/Users/jacek/CORONA/gaia rcbs 2"
col1_name = "Residual X"
col2_name = "Residual Y"
residual_x = df_2['472.52349084947855'].tolist()
residual_y = df_2['708.7060990229543'].tolist()
add_noise_1(folder_path, col1_name, col2_name, residual_x, residual_y)
# Out:
# Checking file: new_Gaia16aau.csv
# DataFrame length: 167, Residual length: 2213
# Padding new_Gaia16aau.csv with 2046 NaN rows.
# Noise added to 'noisey1_new_Gaia16aau.csv'
# Deleted the original file: new_Gaia16aau.csv
# Checking file: new_Gaia18dew.csv
# DataFrame length: 189, Residual length: 2213
# Padding new_Gaia18dew.csv with 2024 NaN rows.
# Noise added to 'noisey1_new_Gaia18dew.csv'
# Deleted the original file: new_Gaia18dew.csv
# Checking file: new_Gaia20ayr.csv
# DataFrame length: 103, Residual length: 2213
# Padding new_Gaia20ayr.csv with 2110 NaN rows.
# Noise added to 'noisey1_new_Gaia20ayr.csv'
# Deleted the original file: new_Gaia20ayr.csv
# Checking file: new_Gaia20bbh.csv
# DataFrame length: 101, Residual length: 2213
# Padding new_Gaia20bbh.csv with 2112 NaN rows.
# Noise added to 'noisey1_new_Gaia20bbh.csv'
# Deleted the original file: new_Gaia20bbh.csv
# Checking file: new_Gaia20bhi.csv
# DataFrame length: 127, Residual length: 2213
# ...

# %%
scale2("C:/Users/jacek/CORONA/gaia rcbs 2")
# Out:
# Checking file: noisey1_new_Gaia16aau.csv
#  '0.95jds noisey1_new_Gaia16aau.csv' scaled by 0.95
#  '1.05jds noisey1_new_Gaia16aau.csv' scaled by 1.05
#  '0.88jds noisey1_new_Gaia16aau.csv' scaled by 0.88
#  '1.07jds noisey1_new_Gaia16aau.csv' scaled by 1.07
#  '1.01jds noisey1_new_Gaia16aau.csv' scaled by 1.01
#  '0.85jds noisey1_new_Gaia16aau.csv' scaled by 0.85
# Checking file: noisey1_new_Gaia18dew.csv
#  '0.95jds noisey1_new_Gaia18dew.csv' scaled by 0.95
#  '1.05jds noisey1_new_Gaia18dew.csv' scaled by 1.05
#  '0.88jds noisey1_new_Gaia18dew.csv' scaled by 0.88
#  '1.07jds noisey1_new_Gaia18dew.csv' scaled by 1.07
#  '1.01jds noisey1_new_Gaia18dew.csv' scaled by 1.01
#  '0.85jds noisey1_new_Gaia18dew.csv' scaled by 0.85
# Checking file: noisey1_new_Gaia20ayr.csv
#  '0.95jds noisey1_new_Gaia20ayr.csv' scaled by 0.95
#  '1.05jds noisey1_new_Gaia20ayr.csv' scaled by 1.05
#  '0.88jds noisey1_new_Gaia20ayr.csv' scaled by 0.88
#  '1.07jds noisey1_new_Gaia20ayr.csv' scaled by 1.07
# ...

# %%
df_3 = pd.read_csv('light_curve_44000.csv')

folder_path = "C:/Users/jacek/CORONA/gaia rcbs 3"
col1_name = "Residual X"
col2_name = "Residual Y"
residual_x = df_3['934.9911397819204'].tolist()
residual_y = df_3['743.8028396870322'].tolist()
add_noise_1(folder_path, col1_name, col2_name, residual_x, residual_y)
# Out:
# Checking file: new_Gaia16aau.csv
# DataFrame length: 167, Residual length: 2213
# Padding new_Gaia16aau.csv with 2046 NaN rows.
# Noise added to 'noisey1_new_Gaia16aau.csv'
# Deleted the original file: new_Gaia16aau.csv
# Checking file: new_Gaia18dew.csv
# DataFrame length: 189, Residual length: 2213
# Padding new_Gaia18dew.csv with 2024 NaN rows.
# Noise added to 'noisey1_new_Gaia18dew.csv'
# Deleted the original file: new_Gaia18dew.csv
# Checking file: new_Gaia20ayr.csv
# DataFrame length: 103, Residual length: 2213
# Padding new_Gaia20ayr.csv with 2110 NaN rows.
# Noise added to 'noisey1_new_Gaia20ayr.csv'
# Deleted the original file: new_Gaia20ayr.csv
# Checking file: new_Gaia20bbh.csv
# DataFrame length: 101, Residual length: 2213
# Padding new_Gaia20bbh.csv with 2112 NaN rows.
# Noise added to 'noisey1_new_Gaia20bbh.csv'
# Deleted the original file: new_Gaia20bbh.csv
# Checking file: new_Gaia20bhi.csv
# DataFrame length: 127, Residual length: 2213
# ...

# %%
scale2("C:/Users/jacek/CORONA/Zenodo rcbs 3")
# Out:
# Checking file: 0.88jds noisey3_lc_wise-toi-1213.csv
#  '0.95jds 0.88jds noisey3_lc_wise-toi-1213.csv' scaled by 0.95
#  '1.05jds 0.88jds noisey3_lc_wise-toi-1213.csv' scaled by 1.05
#  '0.88jds 0.88jds noisey3_lc_wise-toi-1213.csv' scaled by 0.88
#  '1.07jds 0.88jds noisey3_lc_wise-toi-1213.csv' scaled by 1.07
#  '1.01jds 0.88jds noisey3_lc_wise-toi-1213.csv' scaled by 1.01
#  '0.85jds 0.88jds noisey3_lc_wise-toi-1213.csv' scaled by 0.85
# Checking file: 0.88jds noisey3_lc_wise-toi-1225.csv
#  '0.95jds 0.88jds noisey3_lc_wise-toi-1225.csv' scaled by 0.95
#  '1.05jds 0.88jds noisey3_lc_wise-toi-1225.csv' scaled by 1.05
#  '0.88jds 0.88jds noisey3_lc_wise-toi-1225.csv' scaled by 0.88
#  '1.07jds 0.88jds noisey3_lc_wise-toi-1225.csv' scaled by 1.07
#  '1.01jds 0.88jds noisey3_lc_wise-toi-1225.csv' scaled by 1.01
#  '0.85jds 0.88jds noisey3_lc_wise-toi-1225.csv' scaled by 0.85
# Checking file: 0.88jds noisey3_lc_wise-toi-1227.csv
# ...

# %%
df_4 = pd.read_csv('light_curve_40000.csv')

folder_path = "C:/Users/jacek/CORONA/gaia rcbs 4"
col1_name = "Residual X"
col2_name = "Residual Y"
residual_x = df_4['478.3006952153744'].tolist()
residual_y = df_4['594.0680898935875'].tolist()
add_noise_1(folder_path, col1_name, col2_name, residual_x, residual_y)
# Out:
# Checking file: new_Gaia16aau.csv
# DataFrame length: 167, Residual length: 2213
# Padding new_Gaia16aau.csv with 2046 NaN rows.
# Noise added to 'noisey1_new_Gaia16aau.csv'
# Deleted the original file: new_Gaia16aau.csv
# Checking file: new_Gaia18dew.csv
# DataFrame length: 189, Residual length: 2213
# Padding new_Gaia18dew.csv with 2024 NaN rows.
# Noise added to 'noisey1_new_Gaia18dew.csv'
# Deleted the original file: new_Gaia18dew.csv
# Checking file: new_Gaia20ayr.csv
# DataFrame length: 103, Residual length: 2213
# Padding new_Gaia20ayr.csv with 2110 NaN rows.
# Noise added to 'noisey1_new_Gaia20ayr.csv'
# Deleted the original file: new_Gaia20ayr.csv
# Checking file: new_Gaia20bbh.csv
# DataFrame length: 101, Residual length: 2213
# Padding new_Gaia20bbh.csv with 2112 NaN rows.
# Noise added to 'noisey1_new_Gaia20bbh.csv'
# Deleted the original file: new_Gaia20bbh.csv
# Checking file: new_Gaia20bhi.csv
# DataFrame length: 127, Residual length: 2213
# ...

# %%
scale2("C:/Users/jacek/CORONA/gaia rcbs 4")
# Out:
# Checking file: 0.85jds noisey1_new_Gaia16aau.csv
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 scale2("C:/Users/jacek/CORONA/gaia rcbs 4")
#
# Cell In[11], line 21, in scale2(folder_path)
#      18 # Debug: shows that we got this far
#      19 print(f"Checking file: {filename}")
# ---> 21 cols_to_scale = [df.columns[1], df.columns[2], df.columns[3], df.columns[4], df.columns[5], df.columns[6]]
#      22 for col in cols_to_scale:
#      23     df[col] = pd.to_numeric(df[col], errors='coerce') * 0.95
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
#    5391 if isinstance(key, slice):
# ...

# %%
scale2("C:/Users/jacek/CORONA/ms from ROME")
# Out:
# Checking file: light_curve_40000.csv
#  '0.95jds light_curve_40000.csv' scaled by 0.95
#  '1.05jds light_curve_40000.csv' scaled by 1.05
#  '0.88jds light_curve_40000.csv' scaled by 0.88
#  '1.07jds light_curve_40000.csv' scaled by 1.07
#  '1.01jds light_curve_40000.csv' scaled by 1.01
#  '0.85jds light_curve_40000.csv' scaled by 0.85
#  '0.65jds light_curve_40000.csv' scaled by 0.65
#  '0.55jds light_curve_40000.csv' scaled by 0.55
#  '0.75jds light_curve_40000.csv' scaled by 0.75
#  '0.25jds light_curve_40000.csv' scaled by 0.25
#  '0.58jds light_curve_40000.csv' scaled by 0.58
#  '1.28jds light_curve_40000.csv' scaled by 1.28
#  '1.55jds light_curve_40000.csv' scaled by 1.55
#  '1.37jds light_curve_40000.csv' scaled by 1.37
#  '1.43jds light_curve_40000.csv' scaled by 1.43
# Checking file: light_curve_42462.csv
#  '0.95jds light_curve_42462.csv' scaled by 0.95
#  '1.05jds light_curve_42462.csv' scaled by 1.05
#  '0.88jds light_curve_42462.csv' scaled by 0.88
# ...
