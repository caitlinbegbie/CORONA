# %% [markdown]
# # Convert Main Seq LCs to .csv   from Gaia alerts

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
def add_cols(file_path):
    df = pd.read_csv(file_path, comment='#', names=["Date", "JD (TCB)", "avg Mag"])
    df_print = print(df.head(128))
    return df

# %%
Gaia18acn = pd.DataFrame(add_cols('Gaia18acn.csv'))
Gaia19ekz = pd.DataFrame(add_cols('Gaia19ekz.csv'))
Gaia19fcp = pd.DataFrame(add_cols('Gaia19fcp.csv'))
Gaia20aoq = pd.DataFrame(add_cols('Gaia20aoq.csv'))
Gaia20bns = pd.DataFrame(add_cols('Gaia20bns.csv'))
Gaia21ack = pd.DataFrame(add_cols('Gaia21ack.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Gaia18acn = pd.DataFrame(add_cols('Gaia18acn.csv'))
#       2 Gaia19ekz = pd.DataFrame(add_cols('Gaia19ekz.csv'))
#       3 Gaia19fcp = pd.DataFrame(add_cols('Gaia19fcp.csv'))
#
# Cell In[2], line 2, in add_cols(file_path)
#       1 def add_cols(file_path):
# ----> 2     df = pd.read_csv(file_path, comment='#', names=["Date", "JD (TCB)", "avg Mag"])
#       3     df_print = print(df.head(128))
#       4     return df
#
# ...

# %%
new_Gaia18acn = Gaia18acn.to_csv('new_Gaia18acn.csv', index = False)
new_Gaia19ekz = Gaia19ekz.to_csv('new_Gaia19ekz.csv', index = False)
new_Gaia19fcp = Gaia19fcp.to_csv('new_Gaia19fcp.csv', index = False)
new_Gaia20aoq = Gaia20aoq.to_csv('new_Gaia20aoq.csv', index = False)
new_Gaia20bns = Gaia20bns.to_csv('new_Gaia20bns.csv', index = False)
new_Gaia21ack = Gaia21ack.to_csv('new_Gaia21ack.csv', index = False)

# %%
# making new light curves

# stuff for scaling:
for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.07

            # Save the modified DataFrame to a new file
            new_filename = f"1.07jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.07")

# %%
def scale2(folder_path):
    """
    Scales the mag values
    """

    if not os.path.exists(folder_path):
        raise FileNotFoundError(f"The folder '{folder_path}' does not exist.")
    
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            file_path = os.path.join(folder_path, filename)
            try:
                df = pd.read_csv(file_path)
            except pd.errors.EmptyDataError:
                print(f"Warning: '{filename}' is empty and will be skipped.")
                continue

            # Debug: shows that we got this far
            print(f"Checking file: {filename}")

            cols_to_scale = [df.columns[1], df.columns[2]]
            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.95
                
            # Save the modified DataFrame to a new file
            new_filename = f"0.95jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.95")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.05


            # Save the modified DataFrame to a new file
            new_filename = f"1.05jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.05")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.88

            # Save the modified DataFrame to a new file
            new_filename = f"0.88jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.88")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.07

            # Save the modified DataFrame to a new file
            new_filename = f"1.07jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.07")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.01

            # Save the modified DataFrame to a new file
            new_filename = f"1.01jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.01")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 0.85

            # Save the modified DataFrame to a new file
            new_filename = f"0.85jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 0.85")

            for col in cols_to_scale:
                df[col] = pd.to_numeric(df[col], errors='coerce') * 1.09

            # Save the modified DataFrame to a new file
            new_filename = f"1.07jds {filename}"
            new_file_path = os.path.join(folder_path, new_filename)
            df.to_csv(new_file_path, index=False)
            print(f" '{new_filename}' scaled by 1.09")

# %%
scale2("C:/Users/Home/ulab/CORONA/gaia_mainseq")

# %%
# graph to be sure:
df = pd.read_csv('0.88jds new_Gaia19ekz.csv')
new_df = pd.DataFrame(df)
new_df.plot(kind='scatter', x='JD (TCB)', y='avg Mag')
plt.show()

# %% [markdown]
# ## drop cols w/o numbers

# %%
def drop_cols(file_path):
    df = pd.read_csv(file_path)
    df_drop = df.dropna(how='any', axis=0)
    
    name_to_drop = 'untrusted'
    df_untrusted = df_drop[df_drop['avg Mag'] != name_to_drop]
    
    
    df_csv = df_untrusted.to_csv(file_path, index=False)
    return df_untrusted, df_csv

# %%
drop_cols('/Users/Home/ulab/CORONA/gaia_mainseq/new_Gaia19fcp.csv')
# Out:
# (                    Date      JD (TCB) avg Mag
#  4    2015-02-18 23:38:36  2.457072e+06   18.75
#  5    2015-02-19 01:25:10  2.457073e+06   18.67
#  6    2015-03-15 17:35:15  2.457097e+06   18.74
#  7    2015-04-14 11:13:31  2.457127e+06   18.79
#  8    2015-04-14 13:00:05  2.457127e+06   18.75
#  ..                   ...           ...     ...
#  152  2023-08-13 18:41:16  2.460170e+06   18.74
#  153  2023-09-24 11:44:00  2.460212e+06   18.73
#  154  2023-10-24 09:42:43  2.460242e+06   18.76
#  155  2023-11-17 23:30:20  2.460266e+06   18.79
#  156  2023-11-18 03:44:01  2.460267e+06   18.78
#
#  [131 rows x 3 columns],
#  None)

# %%
input_folder = 'C:/Users/Home/ulab/CORONA/gaia_mainseq'
for file in os.listdir(input_folder):
    file_path = os.path.join(input_folder, file)
    drop_cols(file_path)
    print(f'Dropped mean values in {file}')
# Out:
# Dropped mean values in 0.85jds_new_Gaia18acn.csv
# Dropped mean values in 0.85jds_new_Gaia19ekz.csv
# Dropped mean values in 0.85jds_new_Gaia19fcp.csv
# Dropped mean values in 0.85jds_new_Gaia20aoq.csv
# Dropped mean values in 0.85jds_new_Gaia20bns.csv
# Dropped mean values in 0.85jds_new_Gaia21ack.csv
# Dropped mean values in 0.88jds_new_Gaia18acn.csv
# Dropped mean values in 0.88jds_new_Gaia19ekz.csv
# Dropped mean values in 0.88jds_new_Gaia19fcp.csv
# Dropped mean values in 0.88jds_new_Gaia20aoq.csv
# Dropped mean values in 0.88jds_new_Gaia20bns.csv
# Dropped mean values in 0.88jds_new_Gaia21ack.csv
# Dropped mean values in 0.95jds_new_Gaia18acn.csv
# Dropped mean values in 0.95jds_new_Gaia19ekz.csv
# Dropped mean values in 0.95jds_new_Gaia19fcp.csv
# Dropped mean values in 0.95jds_new_Gaia20aoq.csv
# Dropped mean values in 0.95jds_new_Gaia20bns.csv
# Dropped mean values in 0.95jds_new_Gaia21ack.csv
# Dropped mean values in 1.01jds_new_Gaia18acn.csv
# ...

# %%
drop_cols('/Users/Home/ulab/CORONA/gaia_mainseq/new_Gaia18acn.csv')
# Out:
